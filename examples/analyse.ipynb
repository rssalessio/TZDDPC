# %%
import numpy as np
import pickle
import matplotlib.pyplot as plt
import pandas as pd
from scipy.signal import find_peaks

files = ['ZPC', 'TZDDPC', 'STZDDPC1', 'STZDDPC2']

data = {x: {} for x in files}

for x in files:
    with open(f'data_{x}.pkl', 'rb') as f:
        data[x] = pickle.load(f)

# %%
find_peaks(data['STZDDPC1']['memory'][4], 0.9*data['STZDDPC1']['memory'][4].max())[1]['peak_heights']
# Out:
# (array([ 69, 142, 215, 287, 359]),
#  {'peak_heights': array([1172.7578125 , 1172.765625  , 1172.84765625, 1172.7578125 ,
#          1172.75390625])})

# %%
plt.plot(data['STZDDPC1']['memory'][4])
